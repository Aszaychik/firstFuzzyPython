# %% [markdown]
# # FUZZY JOB ROLE SALARY

# %% [markdown]
# IMPORT LIBRARY
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %% [markdown]
# DATASET
# ---

# %%
dataset_salary = pd.read_csv("Salary.csv")
pd.DataFrame(dataset_salary)
# Out:
#         ID                        Role  Years Experience  Salary(in dollar)  \
# 0    ID001           Account Executive                 2                510
# 1    ID002             Account Manager                 1                401
# 2    ID003  Account Support Specialist                 1                360
# 3    ID004              Administration                 2                306
# 4    ID005           Android Developer                 4                374
# ..     ...                         ...               ...                ...
# 116  ID117                 UI Designer                 1                442
# 117  ID118                 UX Engineer                 2                612
# 118  ID119               UX researcher                 1                646
# 119  ID120                Video Editor                 2                544
# 120  ID121               Web Developer                 2                306
#
#     Worth?
# 0        ?
# 1        ?
# 2        ?
# 3        ?
# 4        ?
# ..     ...
# 116      ?
# 117      ?
# 118      ?
# 119      ?
# 120      ?
#
# [121 rows x 5 columns]

# %%
data_role = np.array(dataset_salary)
data_role = data_role [:,[0,1]]
pd.DataFrame(data_role)
# Out:
#          0                           1
# 0    ID001           Account Executive
# 1    ID002             Account Manager
# 2    ID003  Account Support Specialist
# 3    ID004              Administration
# 4    ID005           Android Developer
# ..     ...                         ...
# 116  ID117                 UI Designer
# 117  ID118                 UX Engineer
# 118  ID119               UX researcher
# 119  ID120                Video Editor
# 120  ID121               Web Developer
#
# [121 rows x 2 columns]

# %%
data_exp = np.array(dataset_salary)
data_exp = data_exp [:,[0,2]]
pd.DataFrame(data_exp)
# Out:
#          0  1
# 0    ID001  2
# 1    ID002  1
# 2    ID003  1
# 3    ID004  2
# 4    ID005  4
# ..     ... ..
# 116  ID117  1
# 117  ID118  2
# 118  ID119  1
# 119  ID120  2
# 120  ID121  2
#
# [121 rows x 2 columns]

# %%
data_salary = np.array(dataset_salary)
data_salary = data_salary [:,[0,3]]
pd.DataFrame(data_salary)
# Out:
#          0    1
# 0    ID001  510
# 1    ID002  401
# 2    ID003  360
# 3    ID004  306
# 4    ID005  374
# ..     ...  ...
# 116  ID117  442
# 117  ID118  612
# 118  ID119  646
# 119  ID120  544
# 120  ID121  306
#
# [121 rows x 2 columns]

# %%
role = {}
for i in range (1, data_role[0:,1].size + 1):
    role['role%02d' % i] = np.sum(data_role[i-1:i,1])
    
pd.DataFrame([role])
# Out:
#               role01           role02                      role03  \
# 0  Account Executive  Account Manager  Account Support Specialist
#
#            role04             role05            role06                 role07  \
# 0  Administration  Android Developer  Android Engineer  Application Developer
#
#            role08                     role09  \
# 0  Apps Developer  Associate Product Manager
#
#                                            role10  ...            role112  \
# 0  Associate Research Executive (Market Research)  ...  Technical Auditor
#
#                 role113         role114        role115           role116  \
# 0  Technical Consultant  Technical Lead  Test Engineer  UI / UX Designer
#
#        role117      role118        role119       role120        role121
# 0  UI Designer  UX Engineer  UX researcher  Video Editor  Web Developer
#
# [1 rows x 121 columns]

# %%
exp = {}
for i in range (1, data_exp[0:,1].size + 1):
    exp['exp%02d' % i] = np.sum(data_exp[i-1:i,1])
    
pd.DataFrame([exp])
# Out:
#    exp01  exp02  exp03  exp04  exp05  exp06  exp07  exp08  exp09  exp10  ...  \
# 0      2      1      1      2      4      0      3      1      2      1  ...
#
#    exp112  exp113  exp114  exp115  exp116  exp117  exp118  exp119  exp120  \
# 0       3       4       1       0       2       1       2       1       2
#
#    exp121
# 0       2
#
# [1 rows x 121 columns]

# %%
salary = {}
for i in range (1, data_salary[0:,1].size + 1):
    salary['salary%02d' % i] = np.sum(data_salary[i-1:i,1]) 
    
pd.DataFrame([salary])
# Out:
#    salary01  salary02  salary03  salary04  salary05  salary06  salary07  \
# 0       510       401       360       306       374       272       598
#
#    salary08  salary09  salary10  ...  salary112  salary113  salary114  \
# 0       639       204       374  ...        408        510        340
#
#    salary115  salary116  salary117  salary118  salary119  salary120  salary121
# 0        354        476        442        612        646        544        306
#
# [1 rows x 121 columns]

# %% [markdown]
# MODEL FUZZY
# ---

# %%
def rangeSubject (_low, _high, _step):
    subject = np.arange(_low, _high, _step)
    return subject

def fuzzySalary(_rule, _range_subject, _title, _xlabel):
    lo = fuzz.trimf(_range_subject, _rule[0])
    mi = fuzz.trimf(_range_subject, _rule[1])
    hi = fuzz.trimf(_range_subject, _rule[2])
    
    fig, ax = plt.subplots(1, figsize=(12, 6))
    ax.plot(_range_subject, lo, 'g', label = 'LOW')
    ax.plot(_range_subject, mi, 'b', label = 'AVERAGE')
    ax.plot(_range_subject, hi, 'r', label = 'HIGH')
    
    
    ax.set_title(_title)
    ax.set_xlabel(_xlabel)
    ax.legend()
    
    
    plt.tight_layout()
    return lo,mi,hi

# %%
x_exp = rangeSubject(0,5,1)
r_exp = np.array([
    [0,0,1.3],[0.2,1.5,2.8],[2.7,4,1000]
])

x_salary = rangeSubject(150,700,1)
r_salary = np.array([
    [0,170,340],[273,443,613],[510,680,10000]
])

lo_exp, mi_exp, hi_exp = fuzzySalary(r_exp, x_exp, 'Years Experience','Years')
lo_salary, mi_salary, hi_salary = fuzzySalary(r_salary, x_salary, 'Salary','Value in dollar')

# %%
def funcMem(_range, _lo, _mi, _hi, n):
    lo = fuzz.interp_membership(_range, _lo, n)
    mi = fuzz.interp_membership(_range, _mi, n)
    hi = fuzz.interp_membership(_range, _hi, n)
    
    return lo,mi,hi

def Status(_membership):
    status = ''
    if _membership[0] >= _membership[1] and _membership[0] >= _membership[2]:
        status = 'LOW'
    elif _membership[1] >= _membership[0] and _membership[1] >= _membership[2]:
        status = 'AVERAGE'
    elif _membership[2] >= _membership[0] and _membership[2] >= _membership[1]:
        status = 'HIGH'
        
    return status

# %%
f_exp = {}
s_exp = {}
for i in range (1, len(salary.values())+ 1):
    f_exp['f_exp%02d' % i] = funcMem(x_exp, lo_exp, mi_exp, hi_exp, exp['exp%02d' % i])
    s_exp['s_exp%02d' % i] = Status(f_exp['f_exp%02d' % i])
    print('Years Experience ',['%02d' % i],"(",exp['exp%02d' % i]," Years)",' : ',f_exp['f_exp%02d' % i], s_exp['s_exp%02d' % i])
# Out:
# Years Experience  ['01'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['02'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['03'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['04'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['05'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['06'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['07'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['08'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['09'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['10'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['11'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['12'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['13'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['14'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['15'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['16'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['17'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['18'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['19'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['20'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['21'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['22'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['23'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['24'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['25'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['26'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['27'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['28'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['29'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['30'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['31'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['32'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['33'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['34'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['35'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['36'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['37'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['38'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['39'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['40'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['41'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['42'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['43'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['44'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['45'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['46'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['47'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['48'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['49'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['50'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['51'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['52'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['53'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['54'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['55'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['56'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['57'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['58'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['59'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['60'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['61'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['62'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['63'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['64'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['65'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['66'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['67'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['68'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['69'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['70'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['71'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['72'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['73'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['74'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['75'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['76'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['77'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['78'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['79'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['80'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['81'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['82'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['83'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['84'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['85'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['86'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['87'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['88'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['89'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['90'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['91'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['92'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['93'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['94'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['95'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['96'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['97'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['98'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['99'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['100'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['101'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['102'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['103'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['104'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['105'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['106'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['107'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['108'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['109'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['110'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['111'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['112'] ( 3  Years)  :  (0.0, 0.0, 0.23076923076923067) HIGH
# Years Experience  ['113'] ( 4  Years)  :  (0.0, 0.0, 1.0) HIGH
# Years Experience  ['114'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['115'] ( 0  Years)  :  (1.0, 0.0, 0.0) LOW
# Years Experience  ['116'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['117'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['118'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['119'] ( 1  Years)  :  (0.23076923076923078, 0.6153846153846154, 0.0) AVERAGE
# Years Experience  ['120'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE
# Years Experience  ['121'] ( 2  Years)  :  (0.0, 0.6153846153846153, 0.0) AVERAGE

# %%
f_salary = {}
s_salary = {}
for i in range (1, len(salary.values())+ 1):
    f_salary['f_salary%02d' % i] = funcMem(x_salary, lo_salary, mi_salary, hi_salary, salary['salary%02d' % i])
    s_salary['s_salary%02d' % i] = Status(f_salary['f_salary%02d' % i])
    print('Salary',['%02d' % i],"($",salary['salary%02d' % i],")",' : ',f_salary['f_salary%02d' % i], s_salary['s_salary%02d' % i])
# Out:
# Salary ['01'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['02'] ($ 401 )  :  (0.0, 0.7529411764705882, 0.0) AVERAGE
# Salary ['03'] ($ 360 )  :  (0.0, 0.5117647058823529, 0.0) AVERAGE
# Salary ['04'] ($ 306 )  :  (0.2, 0.19411764705882353, 0.0) LOW
# Salary ['05'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['06'] ($ 272 )  :  (0.4, 0.0, 0.0) LOW
# Salary ['07'] ($ 598 )  :  (0.0, 0.08823529411764706, 0.5176470588235295) HIGH
# Salary ['08'] ($ 639 )  :  (0.0, 0.0, 0.7588235294117647) HIGH
# Salary ['09'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['10'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['11'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['12'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['13'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['14'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['15'] ($ 170 )  :  (1.0, 0.0, 0.0) LOW
# Salary ['16'] ($ 578 )  :  (0.0, 0.20588235294117646, 0.4) HIGH
# Salary ['17'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['18'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['19'] ($ 503 )  :  (0.0, 0.6470588235294118, 0.0) AVERAGE
# Salary ['20'] ($ 560 )  :  (0.0, 0.31176470588235294, 0.29411764705882354) AVERAGE
# Salary ['21'] ($ 224 )  :  (0.6823529411764706, 0.0, 0.0) LOW
# Salary ['22'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['23'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['24'] ($ 320 )  :  (0.11764705882352941, 0.27647058823529413, 0.0) AVERAGE
# Salary ['25'] ($ 578 )  :  (0.0, 0.20588235294117646, 0.4) HIGH
# Salary ['26'] ($ 354 )  :  (0.0, 0.4764705882352941, 0.0) AVERAGE
# Salary ['27'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['28'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['29'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['30'] ($ 449 )  :  (0.0, 0.9647058823529412, 0.0) AVERAGE
# Salary ['31'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['32'] ($ 390 )  :  (0.0, 0.6882352941176471, 0.0) AVERAGE
# Salary ['33'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['34'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['35'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['36'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['37'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['38'] ($ 578 )  :  (0.0, 0.20588235294117646, 0.4) HIGH
# Salary ['39'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['40'] ($ 272 )  :  (0.4, 0.0, 0.0) LOW
# Salary ['41'] ($ 544 )  :  (0.0, 0.40588235294117647, 0.2) AVERAGE
# Salary ['42'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['43'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['44'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['45'] ($ 272 )  :  (0.4, 0.0, 0.0) LOW
# Salary ['46'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['47'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['48'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['49'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['50'] ($ 544 )  :  (0.0, 0.40588235294117647, 0.2) AVERAGE
# Salary ['51'] ($ 299 )  :  (0.2411764705882353, 0.15294117647058825, 0.0) LOW
# Salary ['52'] ($ 544 )  :  (0.0, 0.40588235294117647, 0.2) AVERAGE
# Salary ['53'] ($ 473 )  :  (0.0, 0.8235294117647058, 0.0) AVERAGE
# Salary ['54'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['55'] ($ 585 )  :  (0.0, 0.16470588235294117, 0.4411764705882353) HIGH
# Salary ['56'] ($ 503 )  :  (0.0, 0.6470588235294118, 0.0) AVERAGE
# Salary ['57'] ($ 435 )  :  (0.0, 0.9529411764705882, 0.0) AVERAGE
# Salary ['58'] ($ 306 )  :  (0.2, 0.19411764705882353, 0.0) LOW
# Salary ['59'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['60'] ($ 391 )  :  (0.0, 0.6941176470588235, 0.0) AVERAGE
# Salary ['61'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['62'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['63'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['64'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['65'] ($ 435 )  :  (0.0, 0.9529411764705882, 0.0) AVERAGE
# Salary ['66'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['67'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['68'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['69'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['70'] ($ 374 )  :  (0.0, 0.5941176470588235, 0.0) AVERAGE
# Salary ['71'] ($ 525 )  :  (0.0, 0.5176470588235295, 0.08823529411764706) AVERAGE
# Salary ['72'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['73'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['74'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['75'] ($ 286 )  :  (0.3176470588235294, 0.07647058823529412, 0.0) LOW
# Salary ['76'] ($ 544 )  :  (0.0, 0.40588235294117647, 0.2) AVERAGE
# Salary ['77'] ($ 394 )  :  (0.0, 0.711764705882353, 0.0) AVERAGE
# Salary ['78'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['79'] ($ 653 )  :  (0.0, 0.0, 0.8411764705882353) HIGH
# Salary ['80'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['81'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['82'] ($ 578 )  :  (0.0, 0.20588235294117646, 0.4) HIGH
# Salary ['83'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['84'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['85'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['86'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['87'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['88'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['89'] ($ 503 )  :  (0.0, 0.6470588235294118, 0.0) AVERAGE
# Salary ['90'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['91'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['92'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['93'] ($ 299 )  :  (0.2411764705882353, 0.15294117647058825, 0.0) LOW
# Salary ['94'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['95'] ($ 646 )  :  (0.0, 0.0, 0.8) HIGH
# Salary ['96'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['97'] ($ 385 )  :  (0.0, 0.6588235294117647, 0.0) AVERAGE
# Salary ['98'] ($ 449 )  :  (0.0, 0.9647058823529412, 0.0) AVERAGE
# Salary ['99'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['100'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['101'] ($ 292 )  :  (0.2823529411764706, 0.11176470588235295, 0.0) LOW
# Salary ['102'] ($ 520 )  :  (0.0, 0.5470588235294118, 0.058823529411764705) AVERAGE
# Salary ['103'] ($ 551 )  :  (0.0, 0.36470588235294116, 0.2411764705882353) AVERAGE
# Salary ['104'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['105'] ($ 357 )  :  (0.0, 0.49411764705882355, 0.0) AVERAGE
# Salary ['106'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['107'] ($ 680 )  :  (0.0, 0.0, 1.0) HIGH
# Salary ['108'] ($ 204 )  :  (0.8, 0.0, 0.0) LOW
# Salary ['109'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['110'] ($ 272 )  :  (0.4, 0.0, 0.0) LOW
# Salary ['111'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['112'] ($ 408 )  :  (0.0, 0.7941176470588235, 0.0) AVERAGE
# Salary ['113'] ($ 510 )  :  (0.0, 0.6058823529411764, 0.0) AVERAGE
# Salary ['114'] ($ 340 )  :  (0.0, 0.3941176470588235, 0.0) AVERAGE
# Salary ['115'] ($ 354 )  :  (0.0, 0.4764705882352941, 0.0) AVERAGE
# Salary ['116'] ($ 476 )  :  (0.0, 0.8058823529411765, 0.0) AVERAGE
# Salary ['117'] ($ 442 )  :  (0.0, 0.9941176470588236, 0.0) AVERAGE
# Salary ['118'] ($ 612 )  :  (0.0, 0.0058823529411764705, 0.6) HIGH
# Salary ['119'] ($ 646 )  :  (0.0, 0.0, 0.8) HIGH
# Salary ['120'] ($ 544 )  :  (0.0, 0.40588235294117647, 0.2) AVERAGE
# Salary ['121'] ($ 306 )  :  (0.2, 0.19411764705882353, 0.0) LOW

# %%
dataset_salary
# Out:
#         ID                        Role  Years Experience  Salary(in dollar)  \
# 0    ID001           Account Executive                 2                510
# 1    ID002             Account Manager                 1                401
# 2    ID003  Account Support Specialist                 1                360
# 3    ID004              Administration                 2                306
# 4    ID005           Android Developer                 4                374
# ..     ...                         ...               ...                ...
# 116  ID117                 UI Designer                 1                442
# 117  ID118                 UX Engineer                 2                612
# 118  ID119               UX researcher                 1                646
# 119  ID120                Video Editor                 2                544
# 120  ID121               Web Developer                 2                306
#
#     Worth?
# 0        ?
# 1        ?
# 2        ?
# 3        ?
# 4        ?
# ..     ...
# 116      ?
# 117      ?
# 118      ?
# 119      ?
# 120      ?
#
# [121 rows x 5 columns]

# %%
def worthIt (s_exp, s_salary):
    low_exp = 3
    low_salary = 1
    av_exp = 2
    av_salary = 2
    high_exp = 1
    high_salary = 3
    if s_exp == 'LOW':
        s_exp = low_exp
    elif s_exp == 'AVERAGE':
        s_exp = av_exp
    elif s_exp == 'HIGH':
        s_exp = high_exp

    if s_salary == 'LOW':
        s_salary = low_salary
    elif s_salary == 'AVERAGE':
        s_salary = av_salary
    elif s_salary == 'HIGH':
        s_salary = high_salary
        
    if s_exp + s_salary < 4:
        return 'NO'
    elif s_exp + s_salary == 4:
        return 'YES'
    elif s_exp + s_salary >= 4:
        return 'YES'

# %%
status_data_exp = {}
status_data_salary = {}
new_dataset_salary = dataset_salary
for i in range (0, len(new_dataset_salary['Years Experience'])):
    status_data_exp['status_data_exp%02d' % i] = s_exp['s_exp%02d' % (i+1)]
    status_data_salary['status_data_salary%02d' % i] = s_salary['s_salary%02d' % (i+1)]
    new_dataset_salary['Years Experience'][i] = status_data_exp['status_data_exp%02d' % i]
    new_dataset_salary['Salary(in dollar)'][i] = status_data_salary['status_data_salary%02d' % i]
    new_dataset_salary['Worth?'][i] = worthIt (status_data_exp['status_data_exp%02d' % i], status_data_salary['status_data_salary%02d' % i])

pd.DataFrame(new_dataset_salary)
# Out:
#         ID                        Role Years Experience Salary(in dollar)  \
# 0    ID001           Account Executive          AVERAGE           AVERAGE
# 1    ID002             Account Manager          AVERAGE           AVERAGE
# 2    ID003  Account Support Specialist          AVERAGE           AVERAGE
# 3    ID004              Administration          AVERAGE               LOW
# 4    ID005           Android Developer             HIGH           AVERAGE
# ..     ...                         ...              ...               ...
# 116  ID117                 UI Designer          AVERAGE           AVERAGE
# 117  ID118                 UX Engineer          AVERAGE              HIGH
# 118  ID119               UX researcher          AVERAGE              HIGH
# 119  ID120                Video Editor          AVERAGE           AVERAGE
# 120  ID121               Web Developer          AVERAGE               LOW
#
#     Worth?
# 0      YES
# 1      YES
# 2      YES
# 3       NO
# 4       NO
# ..     ...
# 116    YES
# 117    YES
# 118    YES
# 119    YES
# 120     NO
#
# [121 rows x 5 columns]

# %%
g = sns.FacetGrid(new_dataset_salary,margin_titles=True, col='Salary(in dollar)',col_order=['LOW','AVERAGE','HIGH'], row='Years Experience',row_order=['LOW','AVERAGE','HIGH'])
g = g.map(plt.hist, "Worth?")
plt.tight_layout()

# %%
df_fuzzy_salary = pd.DataFrame(new_dataset_salary)
df_fuzzy_salary.to_excel ('df_fuzzy_salary.xlsx', index = False, header=True)

# %% [markdown]
# ---
# THANKS
# ---
# ---
